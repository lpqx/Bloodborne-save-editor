# %% [markdown]
# <a href="https://colab.research.google.com/github/lpqx/Bloodborne-save-editor/blob/main/mmmm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# 🎵 MMM 在 Google Colab - 纯命令行版
# ============================================================

# 1. 安装依赖
print("📦 安装依赖...")
# !pip install -q numpy scipy librosa soundfile pydub mutagen rich colorama click

# 2. 检查 GPU
import torch
gpu_available = torch.cuda.is_available()
if gpu_available:
    print(f"✅ GPU 可用: {torch.cuda.get_device_name(0)}")
    # !pip install -q cupy-cuda12x torch torchaudio
else:
    print("⚠️ 未检测到 GPU")

# 3. 克隆并安装 MMM
print("\n📥 安装 MMM...")
# !rm -rf /content/mmm
# !git clone -q https://github.com/geeknik/mmm.git /content/mmm
# %cd /content/mmm
# !pip install -q -e .

# 4. 验证安装
print("\n🔍 验证安装...")
# !python -m mmm.cli --version

print("\n" + "="*60)
print("✅ 安装完成！")
print("="*60)
print("\n📖 使用方法:")
print("1. 上传音频文件到 Colab")
print("2. 运行处理命令")
print("\n示例命令:")
print("!python -m mmm.cli obliterate /content/your_file.wav -o /content/cleaned.wav --turbo --paranoid")
print("="*60)
# Out:
# 📦 安装依赖...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 8.3 MB/s eta 0:00:00
# ✅ GPU 可用: Tesla T4
#
# 📥 安装 MMM...
# /content/mmm
#   Preparing metadata (setup.py) ... done
#
# 🔍 验证安装...
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# mmm, version 2.0.0
#
# ...
# ✅ 安装完成！
# ...
#
# 📖 使用方法:
# 1. 上传音频文件到 Colab
# 2. 运行处理命令
#
# 示例命令:
# ...

# %%
# !pip install resampy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 52.3 MB/s eta 0:00:00
# ...

# %%
# !python -m mmm.cli obliterate /content/instvox_duality_v2.flac \
  -o /content/cleaned2.wav \
  --turbo --paranoid \
  --gated-resample-nudge \
  --no-phase-noise \
  --no-phase-swirl \
  --no-transient-shift \
  --no-micro-eq-flutter \
  --no-phase-dither \
  --no-masked-hf-phase \
  --no-hf-decorrelate \
  --verify
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────╮
# │                                                                              │
# │╔═════════════════════════════════════════════════════════════════════════════│
# │══╗                                                                           │
# │║                                                                             │
# │║                                                                             │
# │║   ┌─────────────────────────────────────────────────────────────────────┐   │
# │║                                                                             │
# │║   │                                                                     │   │
# │║                                                                             │
# │║   │  🎵♪   MELODIC METADATA MASSACRER v2.0   ♫♪                        │    │
# │║                                                                             │
# ...
